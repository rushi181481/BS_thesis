# %% [markdown]
# Learning Difficulty index

# %%
import pandas as pd

df = pd.read_csv("/home/bs_thesis/Desktop/Rushi/BS_thesis/Survey on English Languages Diffculties in Telugu States.csv")

df = df.drop("Timestamp", axis=1)
df.head()
# Out:
#   Age group  Gender Medium of School   \
# 0     15-19    Male    English medium
# 1     20-25  Female    English medium
# 2     20-25    Male    English medium
# 3     20-25    Male    English medium
# 4     20-25    Male    English medium
#
#    How difficult is it for you to understanding English conversation?\nఆంగ్ల సంభాషణను అర్థం చేసుకోవడం మీకు ఎంత కష్టం?  \
# 0                                                  2
# 1                                                  2
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#    How difficult do you find it to speak English confidently while discussing passages or articles?\nప్యాసేజ్‌లు లేదా వ్యాసాల గురించి మాట్లాడేటప్పుడు, ఆత్మవిశ్వాసంతో ఇంగ్లీష్ మాట్లాడటం మీకు ఎంత కష్టం?  \
# 0                                                  5
# 1                                                  3
# 2                                                  1
# 3                                                  4
# 4                                                  4
#
#    How difficult is it for you to write sentences in English?\nమీకు ఆంగ్లంలో వాక్యాలు రాయడం ఎంత కష్టం?  \
# 0                                                  3
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  3
#
#    How difficult is it for you to read and understand English passages or articles?\nఇంగ్లీష్ పేరాగ్రాఫ్‌లు లేదా వ్యాసాలను చదివి అర్థం చేసుకోవడం మీకు ఎంత కష్టం?  \
# 0                                                  2
# 1                                                  2
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#    How difficult is it for you to use English due to the influence of your mother tongue (Telugu)?\nమీ మాతృభాష (తెలుగు) ప్రభావం వల్ల మీకు ఇంగ్లీష్ ఉపయోగించడం ఎంత కష్టంగా ఉంటుంది?  \
# 0                                                  4
# 1                                                  3
# 2                                                  1
# 3                                                  3
# 4                                                  1
#
#    How difficult is it for you to understand lectures in English?\nఇంగ్లీషులో ఉపన్యాసాలను అర్థం చేసుకోవడం మీకు ఎంత కష్టం?  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#    How difficult is it for you to watch English movies without subtitles?\nసబ్‌టైటిల్స్ లేకుండా ఇంగ్లీష్ సినిమాలు చూడటం మీకు ఎంత కష్టం?  \
# 0                                                  2
# 1                                                  3
# 2                                                  1
# 3                                                  2
# 4                                                  2
#
#    How difficult is it for you to watch English movies even with subtitles?\nసబ్‌టైటిల్స్‌తో చూసినప్పటికీ, మీకు ఇంగ్లీష్ సినిమాలు చూడటం ఎంత కష్టంగా ఉంటుంది?  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#    How do you feel while learning English?\nఇంగ్లీష్ నేర్చుకునేటప్పుడు మీకు ఎలా అనిపిస్తుంది?  \
# 0                                                  2
# 1                                                  1
# 2                                                  5
# 3                                                  2
# 4                                                  2
#
#    As a Telugu medium student, how difficult was it for you to switch to an English-Medium Curriculum in higher studies?\nతెలుగు మాధ్యమంలో చదివిన విద్యార్థిగా, ఉన్నత విద్యలో ఆంగ్ల మాధ్యమ పాఠ్య ప్రణాళికకు మారడం మీకు ఎంత కష్టంగా అనిపించింది?  \
# 0                                                  1
# 1                                                  1
# 2                                                  5
# 3                                                  1
# 4                                                  1
#
#    How difficult do you find it to work in other Indian states due to language differences?\nభాషా భేదాల కారణంగా ఇతర భారతీయ రాష్ట్రాలలో పని చేయడం మీకు ఎంత కష్టంగా అనిపిస్తుంది?  \
# 0                                                  4
# 1                                                  2
# 2                                                  4
# 3                                                  4
# 4                                                  4
#
#    How difficult do you find it to work in other countries due to language differences?\nభాషా భేదాల కారణంగా ఇతర దేశాలలో పనిచేయడం మీకు ఎంత కష్టంగా అనిపిస్తుంది?  \
# 0                                                  4
# 1                                                  3
# 2                                                  4
# 3                                                  4
# 4                                                  4
#
#    How difficult do you find it to study in other Indian states or other countries due to language differences?\nభాషా భేదాల కారణంగా ఇతర భారతీయ రాష్ట్రాలలో లేదా ఇతర దేశాలలో చదువుకోవడం మీకు ఎంత కష్టంగా అనిపిస్తుంది?  \
# 0                                                  4
# 1                                                  2
# 2                                                  4
# 3                                                  4
# 4                                                  3
#
#    How difficult do you find it to make friends who have different native languages?\nవేర్వేరు మాతృభాషలు ఉన్నవారితో స్నేహం చేయడం మీకు ఎంత కష్టంగా అనిపిస్తుంది?
# 0                                                  3
# 1                                                  2
# 2                                                  5
# 3                                                  3
# 4                                                  3

# %%
df = df.rename(columns={
"How difficult is it for you to understanding English conversation?\nఆంగ్ల సంభాషణను అర్థం చేసుకోవడం మీకు ఎంత కష్టం?":"Conv_diff",

"How difficult do you find it to speak English confidently while discussing passages or articles?\nప్యాసేజ్‌లు లేదా వ్యాసాల గురించి మాట్లాడేటప్పుడు, ఆత్మవిశ్వాసంతో ఇంగ్లీష్ మాట్లాడటం మీకు ఎంత కష్టం?":"Speak_diff",

"How difficult is it for you to write sentences in English?\nమీకు ఆంగ్లంలో వాక్యాలు రాయడం ఎంత కష్టం?": "Write_diff",

"How difficult is it for you to read and understand English passages or articles?\nఇంగ్లీష్ పేరాగ్రాఫ్‌లు లేదా వ్యాసాలను చదివి అర్థం చేసుకోవడం మీకు ఎంత కష్టం?":"Read_diff",

"How difficult is it for you to use English due to the influence of your mother tongue (Telugu)?\nమీ మాతృభాష (తెలుగు) ప్రభావం వల్ల మీకు ఇంగ్లీష్ ఉపయోగించడం ఎంత కష్టంగా ఉంటుంది?": "MT_influence",

"How difficult is it for you to understand lectures in English?\nఇంగ్లీషులో ఉపన్యాసాలను అర్థం చేసుకోవడం మీకు ఎంత కష్టం?": "Lect_diff",

"How difficult is it for you to watch English movies without subtitles?\nసబ్‌టైటిల్స్ లేకుండా ఇంగ్లీష్ సినిమాలు చూడటం మీకు ఎంత కష్టం?": "Movie_Nosub",

"How difficult is it for you to watch English movies even with subtitles?\nసబ్‌టైటిల్స్‌తో చూసినప్పటికీ, మీకు ఇంగ్లీష్ సినిమాలు చూడటం ఎంత కష్టంగా ఉంటుంది?": "Movie_sub",

"How do you feel while learning English?\nఇంగ్లీష్ నేర్చుకునేటప్పుడు మీకు ఎలా అనిపిస్తుంది?":"Learning_feel",

"As a Telugu medium student, how difficult was it for you to switch to an English-Medium Curriculum in higher studies?\nతెలుగు మాధ్యమంలో చదివిన విద్యార్థిగా, ఉన్నత విద్యలో ఆంగ్ల మాధ్యమ పాఠ్య ప్రణాళికకు మారడం మీకు ఎంత కష్టంగా అనిపించింది?":"Switch_diff",

"How difficult do you find it to work in other Indian states due to language differences?\nభాషా భేదాల కారణంగా ఇతర భారతీయ రాష్ట్రాలలో పని చేయడం మీకు ఎంత కష్టంగా అనిపిస్తుంది?":"work_india",

"How difficult do you find it to work in other countries due to language differences?\nభాషా భేదాల కారణంగా ఇతర దేశాలలో పనిచేయడం మీకు ఎంత కష్టంగా అనిపిస్తుంది?":"Work_abroad",

"How difficult do you find it to study in other Indian states or other countries due to language differences?\nభాషా భేదాల కారణంగా ఇతర భారతీయ రాష్ట్రాలలో లేదా ఇతర దేశాలలో చదువుకోవడం మీకు ఎంత కష్టంగా అనిపిస్తుంది?":"Study_other",

"How difficult do you find it to make friends who have different native languages?\nవేర్వేరు మాతృభాషలు ఉన్నవారితో స్నేహం చేయడం మీకు ఎంత కష్టంగా అనిపిస్తుంది?":"Friend_diff"})

# %%
difficulty_Cols = [
    "Read_diff", 
    "Write_diff",
    "Conv_diff",
    "Lect_diff",
    "Speak_diff"]

df["Learning_difficulty_index"]= df[difficulty_Cols].mean(axis=1)

# %%
df["Learning_difficulty_index"].describe()
# Out:
# count    483.000000
# mean       2.249275
# std        0.932479
# min        1.000000
# 25%        1.400000
# 50%        2.200000
# 75%        3.000000
# max        5.000000
# Name: Learning_difficulty_index, dtype: float64

# %%
def categorize(x):
    if x < 2:
        return "Low"
    elif x < 3.5:
        return "Medium"
    else:
        return "High"

df["LDI_Level"] = df["Learning_difficulty_index"].apply(categorize)

# %%
df
# Out:
#     Age group  Gender Medium of School   Conv_diff  Speak_diff  Write_diff  \
# 0       15-19    Male    English medium          2           5           3
# 1       20-25  Female    English medium          2           3           1
# 2       20-25    Male    English medium          1           1           1
# 3       20-25    Male    English medium          1           4           1
# 4       20-25    Male    English medium          1           4           3
# ..        ...     ...               ...        ...         ...         ...
# 478     15-19  Female              Both          2           1           2
# 479     15-19  Female    English medium          2           3           1
# 480     15-19  Female              Both          3           4           2
# 481     15-19  Female    English medium          3           3           2
# 482     15-19  Female    English medium          3           2           1
#
#      Read_diff  MT_influence  Lect_diff  Movie_Nosub  Movie_sub  \
# 0            2             4          1            2          1
# 1            2             3          1            3          1
# 2            1             1          1            1          1
# 3            1             3          1            2          1
# 4            1             1          1            2          1
# ..         ...           ...        ...          ...        ...
# 478          4             2          4            2          2
# 479          2             1          2            3          4
# 480          2             3          2            4          2
# 481          5             2          2            3          4
# 482          3             2          4            4          4
#
#      Learning_feel  Switch_diff  work_india  Work_abroad  Study_other  \
# 0                2            1           4            4            4
# 1                1            1           2            3            2
# 2                5            5           4            4            4
# 3                2            1           4            4            4
# 4                2            1           4            4            3
# ..             ...          ...         ...          ...          ...
# 478              1            1           1            1            2
# 479              3            2           4            5            5
# 480              1            2           4            2            3
# 481              5            4           3            2            4
# 482              4            3           3            3            3
#
#      Friend_diff  Learning_difficulty_index LDI_Level
# 0              3                        2.6    Medium
# 1              2                        1.8       Low
# 2              5                        1.0       Low
# 3              3                        1.6       Low
# 4              3                        2.0    Medium
# ..           ...                        ...       ...
# 478            4                        2.6    Medium
# 479            3                        2.0    Medium
# 480            1                        2.6    Medium
# 481            1                        3.0    Medium
# 482            4                        2.6    Medium
#
# [483 rows x 19 columns]

# %%
df["LDI_Level"].value_counts()
# Out:
# LDI_Level
# Medium    257
# Low       175
# High       51
# Name: count, dtype: int64

# %%
df["LDI_Level"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='LDI_Level'>

# %% [markdown]
# SKill Gap analysis

# %%
df["Read_skill"]  = 5 - df["Read_diff"]
df["Write_skill"] = 5 - df["Write_diff"]
df["Speak_skill"] = 5 - df["Speak_diff"]
df["Lect_skill"]  = 5- df["Lect_diff"]
df["conv_skill"]  = 5 - df["Conv_diff"]

# %%
skill_cols = ["Read_skill", "Write_skill", "Speak_skill", "Lect_skill","conv_skill"]

expected = df[skill_cols].quantile(0.75).mean()

for col in skill_cols:
    df[col + "_gap"] = expected - df[col]

# %%
expected
# Out:
# np.float64(3.8)

# %%
gap_cols = [col + "_gap" for col in skill_cols]

df["core_Skill_Gap"] = df[gap_cols].mean(axis=1)

# %%
def categorize_gap(x):
    if x > 2:
        return "High Gap"
    elif x > 1:
        return "Medium Gap"
    else:
        return "Low Gap"

df["Gap_Level"] = df["core_Skill_Gap"].apply(categorize_gap)

# %%
df[gap_cols].mean()
# Out:
# Read_skill_gap     0.955280
# Write_skill_gap    0.975983
# Speak_skill_gap    1.311387
# Lect_skill_gap     1.093996
# conv_skill_gap     0.909731
# dtype: float64

# %%
df["Gap_Level"].value_counts()
# Out:
# Gap_Level
# Low Gap       266
# Medium Gap    151
# High Gap       66
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x="Gap_Level", data=df)
plt.title("Student Skill Gap Distribution")
plt.show()

# %%
df
# Out:
#     Age group  Gender Medium of School   Conv_diff  Speak_diff  Write_diff  \
# 0       15-19    Male    English medium          2           5           3
# 1       20-25  Female    English medium          2           3           1
# 2       20-25    Male    English medium          1           1           1
# 3       20-25    Male    English medium          1           4           1
# 4       20-25    Male    English medium          1           4           3
# ..        ...     ...               ...        ...         ...         ...
# 478     15-19  Female              Both          2           1           2
# 479     15-19  Female    English medium          2           3           1
# 480     15-19  Female              Both          3           4           2
# 481     15-19  Female    English medium          3           3           2
# 482     15-19  Female    English medium          3           2           1
#
#      Read_diff  MT_influence  Lect_diff  Movie_Nosub  ...  Speak_skill  \
# 0            2             4          1            2  ...            0
# 1            2             3          1            3  ...            2
# 2            1             1          1            1  ...            4
# 3            1             3          1            2  ...            1
# 4            1             1          1            2  ...            1
# ..         ...           ...        ...          ...  ...          ...
# 478          4             2          4            2  ...            4
# 479          2             1          2            3  ...            2
# 480          2             3          2            4  ...            1
# 481          5             2          2            3  ...            2
# 482          3             2          4            4  ...            3
#
#      Lect_skill  conv_skill  Read_skill_gap  Write_skill_gap  Speak_skill_gap  \
# 0             4           3             0.8              1.8              3.8
# 1             4           3             0.8             -0.2              1.8
# 2             4           4            -0.2             -0.2             -0.2
# 3             4           4            -0.2             -0.2              2.8
# 4             4           4            -0.2              1.8              2.8
# ..          ...         ...             ...              ...              ...
# 478           1           3             2.8              0.8             -0.2
# 479           3           3             0.8             -0.2              1.8
# 480           3           2             0.8              0.8              2.8
# 481           3           2             3.8              0.8              1.8
# 482           1           2             1.8             -0.2              0.8
#
#      Lect_skill_gap  conv_skill_gap core_Skill_Gap   Gap_Level
# 0              -0.2             0.8            1.4  Medium Gap
# 1              -0.2             0.8            0.6     Low Gap
# 2              -0.2            -0.2           -0.2     Low Gap
# 3              -0.2            -0.2            0.4     Low Gap
# 4              -0.2            -0.2            0.8     Low Gap
# ..              ...             ...            ...         ...
# 478             2.8             0.8            1.4  Medium Gap
# 479             0.8             0.8            0.8     Low Gap
# 480             0.8             1.8            1.4  Medium Gap
# 481             0.8             1.8            1.8  Medium Gap
# 482             2.8             1.8            1.4  Medium Gap
#
# [483 rows x 31 columns]

# %% [markdown]
# Clustering

# %%
X_ldi = df[["Learning_difficulty_index"]]

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters= 3, random_state = 42)
df["LDI_cluster"]= kmeans.fit_predict(X_ldi)

# %% [markdown]
# Clustering of skill gap

# %%
features = [
    "Read_skill_gap",
    "Write_skill_gap",
    "Speak_skill_gap",
    "Lect_skill_gap",
    "conv_skill_gap"
]

# %%
X = df[features].dropna()

# %%
X
# Out:
#      Read_skill_gap  Write_skill_gap  Speak_skill_gap  Lect_skill_gap  \
# 0               0.8              1.8              3.8            -0.2
# 1               0.8             -0.2              1.8            -0.2
# 2              -0.2             -0.2             -0.2            -0.2
# 3              -0.2             -0.2              2.8            -0.2
# 4              -0.2              1.8              2.8            -0.2
# ..              ...              ...              ...             ...
# 478             2.8              0.8             -0.2             2.8
# 479             0.8             -0.2              1.8             0.8
# 480             0.8              0.8              2.8             0.8
# 481             3.8              0.8              1.8             0.8
# 482             1.8             -0.2              0.8             2.8
#
#      conv_skill_gap
# 0               0.8
# 1               0.8
# 2              -0.2
# 3              -0.2
# 4              -0.2
# ..              ...
# 478             0.8
# 479             0.8
# 480             1.8
# 481             1.8
# 482             1.8
#
# [483 rows x 5 columns]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.cluster import KMeans


inertia =[]

K_range= range(1,10)

for K in K_range:
    kMeans = KMeans(n_clusters= K, random_state = 42, n_init= 10)
    kMeans.fit(X_scaled)
    inertia.append(kMeans.inertia_)

# %%
import matplotlib.pyplot as plt

plt.plot(K_range, inertia, marker='o')
plt.xlabel("Number of Clusters (K)")
plt.ylabel("inertia")
plt.title("Elbow method")
plt.show()

# %%
kmeans = KMeans(n_clusters= 3, random_state=42)
df["cluster"]= kmeans.fit_predict(X_scaled)

# %%
df["cluster"].value_counts()
# Out:
# cluster
# 1    231
# 2    181
# 0     71
# Name: count, dtype: int64

# %%
df.groupby("cluster")[features].mean()
# Out:
#          Read_skill_gap  Write_skill_gap  Speak_skill_gap  Lect_skill_gap  \
# cluster
# 0              2.757746         2.433803         2.602817        2.785915
# 1              0.146320         0.137662         0.613853        0.289177
# 2              1.280663         1.474033         1.695028        1.457459
#
#          conv_skill_gap
# cluster
# 0              2.673239
# 1              0.172294
# 2              1.159116

# %%
from sklearn.manifold import TSNE

tsne = TSNE(n_components =2, random_state = 42)
X_tsne = tsne.fit_transform(X_scaled)

plt.figure(figsize=(8,8))

plt.scatter(
    X_tsne[:,0],
    X_tsne[:,1],
    c= df["cluster"],
    cmap= "Set1",
    s=50
)

plt.title("cluster")
plt.colorbar(label= "cluster")
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df["cluster"].value_counts()
# Out:
# cluster
# 1    231
# 2    181
# 0     71
# Name: count, dtype: int64

# %% [markdown]
# medium comparison

# %%
df["Medium of School "].value_counts()
# Out:
# Medium of School
# English medium    402
# Both               56
# Telugu medium      25
# Name: count, dtype: int64

# %%
df.groupby("Medium of School ")[[
    "Read_skill_gap",
    "Write_skill_gap",
    "Speak_skill_gap",
    "Lect_skill_gap",
    "core_Skill_Gap",
    "conv_skill_gap"
]].mean()
# Out:
#                    Read_skill_gap  Write_skill_gap  Speak_skill_gap  \
# Medium of School
# Both                     1.282143         1.157143         1.657143
# English medium           0.894527         0.929353         1.235323
# Telugu medium            1.200000         1.320000         1.760000
#
#                    Lect_skill_gap  core_Skill_Gap  conv_skill_gap
# Medium of School
# Both                     1.550000        1.367857        1.192857
# English medium           1.001493        0.981592        0.847264
# Telugu medium            1.560000        1.424000        1.280000

# %%
import matplotlib.pyplot as plt 

medium_avg  = df.groupby("Medium of School ")[[
    "Read_skill_gap",
    "Write_skill_gap",
    "Speak_skill_gap",
    "Lect_skill_gap",
    "conv_skill_gap"
]].mean()


medium_avg.plot(kind="bar",figsize=(10,6))


plt.title("skill gap comparison with meduim ")
plt.ylabel("skill gap")
plt.xticks(rotation = 0)
plt.legend(title="skills")
plt.show()

# %%
import seaborn as sns

sns.boxplot(x="Medium of School ", y="Speak_skill_gap", data=df)

plt.title("Speaking Skill Gap by Medium")
plt.show()

# %%
import seaborn as sns

sns.boxplot(x="Medium of School ", y="Read_skill_gap", data=df)

plt.title("Reading Skill Gap by Medium")
plt.show()

# %%
import seaborn as sns

sns.boxplot(x="Medium of School ", y="Write_skill_gap", data=df)

plt.title("Writing Skill Gap by Medium")
plt.show()

# %%
import seaborn as sns

sns.boxplot(x="Medium of School ", y="conv_skill_gap", data=df)

plt.title("conversation Skill Gap by Medium")
plt.show()

# %%
import seaborn as sns

sns.boxplot(x="Medium of School ", y="Lect_skill_gap", data=df)

plt.title("Lecture Understanding Skill Gap by Medium")
plt.show()

# %%
pd.crosstab(df["Medium of School "], df["cluster"], normalize='index')
# Out:
# cluster                   0         1         2
# Medium of School
# Both               0.250000  0.303571  0.446429
# English medium     0.126866  0.509950  0.363184
# Telugu medium      0.240000  0.360000  0.400000

# %%
pd.crosstab(df["Medium of School "], df["LDI_cluster"], normalize='index')
# Out:
# LDI_cluster               0         1         2
# Medium of School
# Both               0.410714  0.232143  0.357143
# English medium     0.221393  0.383085  0.395522
# Telugu medium      0.400000  0.320000  0.280000

# %%
df.to_csv('survey daataset of skill gap.csv', index = "False")
